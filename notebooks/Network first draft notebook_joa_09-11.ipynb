# %%
#Import libraries
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

# %%
# Create a small synthetic dataset with white noise and square labeled masks
def create_synthetic_dataset(num_samples=100, image_size=(100, 100), particle_size=10, noise_level=0.2):
    dataset = []

    for _ in range(num_samples):
        image = noise_level * torch.randn(1, *image_size)
        x, y = np.random.randint(0, image_size[0] - particle_size), np.random.randint(0, image_size[1] - particle_size)
        image[ 0, x:x + particle_size, y:y + particle_size] = 1.0

        #save the mask as label
        label = torch.zeros(1, *image_size)
        label[0, x:x + particle_size, y:y + particle_size] = 1.0
        
        

        dataset.append((image, label))

    return dataset

# %%
# Create synthetic data that emulates the real data (Joachim's code)
#Created directly in torch
CamDataNormalizedCumalative = torch.from_numpy(np.load('CamDataNormalizedCumalative.npy'))

def rdNoise(CamDataNormalizedCumalative, Shape):
    if isinstance(Shape, int):
        rdNumb = torch.searchsorted(CamDataNormalizedCumalative[:, 0], torch.rand(size=(Shape,)))
        return rdNumb
    else:
        Sizelength = Shape[0] * Shape[1]
        rdNumb = torch.searchsorted(CamDataNormalizedCumalative[:, 0], torch.rand(size=(Sizelength,)))
        rdNumb = rdNumb.reshape(Shape)
        return rdNumb

def gaussian(pos, mu, params):
    x, y = pos
    x0, y0 = mu
    A, sigma = params
    return A * torch.exp(-((x - x0) ** 2 + (y - y0) ** 2) / (2 * sigma ** 2))

def generate_images(num_images=5, x_dim=100, y_dim=100, num_gaussians=100, gauss_params=(50, 1)):
    dataset = []
    images = []
    positions_list = []
    gauss_masks = []
    flowrate = 5+max(min(random.gauss(0, 1), 2), -2)
    Angle = random.uniform(0, 2 * np.pi)
    flowX = flowrate * np.cos(Angle)
    flowY = flowrate * np.sin(Angle)
    Init_positions = torch.zeros((2, num_gaussians))
    Init_positions[0, :] = torch.rand(num_gaussians) * x_dim
    Init_positions[1, :] = torch.rand(num_gaussians) * y_dim
    for i in range(num_images):
        sim_domain = torch.zeros((x_dim, y_dim))
        positions = torch.zeros((2, num_gaussians))
        positions[0, :] = torch.randint(0, x_dim, (num_gaussians,))
        positions[1, :] = torch.randint(0, y_dim, (num_gaussians,))
        print(positions)
        x = torch.arange(x_dim)
        y = torch.arange(y_dim)
        x, y = torch.meshgrid(x, y)

        for n in range(num_gaussians):
            sim_domain += gaussian((x, y), positions[:, n], gauss_params).t()

        # Store the images and masks as tensors with 1 channel
        #noise = torch.normal(mean=0., std=noise_stddev, size=sim_domain.shape)
        noise = rdNoise(CamDataNormalizedCumalative, sim_domain.shape)
        


        # Store the images and masks as tensors with 1 channel
        dataset.append((sim_domain.unsqueeze(0) + 1.0*noise,sim_domain.unsqueeze(0)))
        positions_list.append(positions)
    print(positions_list)
    return dataset

# %%
num_gaussians = 10
x_dim = 100
y_dim = 100
positions = torch.zeros((2, num_gaussians))
positions[0, :] = torch.randint(0, x_dim, (num_gaussians,))
positions[1, :] = torch.randint(0, y_dim, (num_gaussians,))
#print(positions)

# %%
import math

flowrate = 5+max(min(random.gauss(0, 1), 2), -2)
Angle = random.uniform(0, 2 * math.pi)

# Define polar coordinates
r = 5
theta = math.pi/4  # 45 degrees in radians

# Convert to cartesian coordinates
x = r * math.cos(theta)
y = r * math.sin(theta)

# Print the result
print(f"({x}, {y})")
# Out:
# -1.5024111718860462

# %%
Data_plus_label=generate_images(3,25,25, num_gaussians=2, gauss_params=(50, 1))
#print(Data_plus_label[0][0],Data_plus_label[0][1])
# Out:
# tensor([[17.,  8.],
#         [ 9.,  5.]])
# tensor([[ 8., 16.],
#         [ 3.,  5.]])
# tensor([[20., 15.],
#         [ 8.,  2.]])

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def init(self, num_samples=1000, transform=None):
        self.num_samples = num_samples
        #self.transform = transform

    def len(self):
        return self.num_samples

    def getitem(self, idx):
        # Generate your data here
        # For example, let's generate a random tensor as data
        Data_plus_label=generate_images(num_images, x_dim, y_dim, num_gaussians=100, gauss_params=(50, 1))
        #print(Data_plus_label.shape)
        data = Data_plus_label[0][0] # 3 channels, 64x64 image

        if self.transform:
            data = self.transform(data)

        # For simplicity, let's assume all samples have the same label (0 in this case)
        label = Data_plus_label[0][1] 

        return data, label

#Define a transform if needed
#transform = transforms.Compose([transforms.ToTensor(),])

#Create an instance of your custom dataset
custom_dataset = CustomDataset(num_samples=1000, transform=transform)

#Create a DataLoader for your custom dataset
custom_dataloader = DataLoader(custom_dataset, batch_size=64, shuffle=True)

#Now you can iterate over the dataloader to get batches of generated data
for batch in custom_dataloader:
    generated_data, labels = batch
    # Your training/validation/testing logic goes here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\s174006\OneDrive - Danmarks Tekniske Universitet\PhD\Courses\Deeplearning\Final Project\particle_tracking_02456\notebooks\Network first draft notebook_joa_09-11.ipynb Cell 6 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/s174006/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/PhD/Courses/Deeplearning/Final%20Project/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook_joa_09-11.ipynb#X23sZmlsZQ%3D%3D?line=24'>25</a>         return data, label
#      <a href='vscode-notebook-cell:/c%3A/Users/s174006/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/PhD/Courses/Deeplearning/Final%20Project/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook_joa_09-11.ipynb#X23sZmlsZQ%3D%3D?line=26'>27</a> #Define a transform if needed
#      <a href='vscode-notebook-cell:/c%3A/Users/s174006/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/PhD/Courses/Deeplearning/Final%20Project/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook_joa_09-11.ipynb#X23sZmlsZQ%3D%3D?line=27'>28</a> #transform = transforms.Compose([transforms.ToTensor(),])
#      <a href='vscode-notebook-cell:/c%3A/Users/s174006/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/PhD/Courses/Deeplearning/Final%20Project/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook_joa_09-11.ipynb#X23sZmlsZQ%3D%3D?line=28'>29</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/s174006/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/PhD/Courses/Deeplearning/Final%20Project/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook_joa_09-11.ipynb#X23sZmlsZQ%3D%3D?line=29'>30</a> #Create an instance of your custom dataset
# ---> <a href='vscode-notebook-cell:/c%3A/Users/s174006/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/PhD/Courses/Deeplearning/Final%20Project/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook_joa_09-11.ipynb#X23sZmlsZQ%3D%3D?line=30'>31</a> custom_dataset = CustomDataset(num_samples=1000, transform=transform)
#      <a href='vscode-notebook-cell:/c%3A/Users/s174006/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/PhD/Courses/Deeplearning/Final%20Project/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook_joa_09-11.ipynb#X23sZmlsZQ%3D%3D?line=32'>33</a> #Create a DataLoader for your custom dataset
#      <a href='vscode-notebook-cell:/c%3A/Users/s174006/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/PhD/Courses/Deeplearning/Final%20Project/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook_joa_09-11.ipynb#X23sZmlsZQ%3D%3D?line=33'>34</a> custom_dataloader = DataLoader(custom_dataset, batch_size=64, shuffle=True)
#
# NameError: name 'transform' is not defined

# %%
# Visualize an image and its corresponding label mask
def visualize_image(image, label):
    plt.figure()
    plt.title("Particle Detection")
    plt.subplot(1, 2, 1)
    plt.imshow(image[0].numpy(), cmap='gray')
    plt.title("Image")
    plt.subplot(1, 2, 2)
    plt.imshow(label[0].numpy(), cmap='gray')
    plt.title("Label Mask (Particle)")

# Create and visualize the dataset
#dataset = create_synthetic_dataset(num_samples=2)
dataset = generate_images(2, 100, 100)
image, label = dataset[0]
visualize_image(image, label)
# print the type of dataset
print(dataset[0][1].shape)
#print the range of values in the image
print(torch.max(dataset[0][0]))
print(torch.min(dataset[0][0]))

plt.show()
# Out:
# C:\Users\s174006\AppData\Local\Temp\ipykernel_18728\3217701344.py:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)
# torch.Size([1, 100, 100])
# tensor(91.8091)
# tensor(0.)

# %%
#Define UNet model architecture

class ParticleDetectionUNet(nn.Module):
    def __init__(self, in_channels=1, out_channels=1, features=64):
        super(ParticleDetectionUNet, self).__init__()
        
        # Encoder (downsampling)
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, features, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(features, features, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        # Bottleneck
        self.bottleneck = nn.Sequential(
            nn.Conv2d(features, features * 2, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(features * 2, features * 2, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        
        # Decoder (upsampling)
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(features * 2, features, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(features, out_channels, kernel_size=1)  # Output layer
        )

    def forward(self, x):
        # Encoder
        x1 = self.encoder(x)
        
        # Bottleneck
        x2 = self.bottleneck(x1)
        
        # Decoder
        x3 = self.decoder(x2)
        
        return x3

# Instantiate the model
model = ParticleDetectionUNet()

# %%
#Train the model with first type of data and plot the training and validation loss

# Define the model, loss function, and optimizer
model = ParticleDetectionUNet()
criterion = nn.BCEWithLogitsLoss()  # Binary Cross-Entropy Loss
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Load the synthetic training dataset
train_dataset = create_synthetic_dataset(num_samples=300)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True)

# Load a separate validation dataset
validation_dataset = create_synthetic_dataset(num_samples=20)  # Adjust the size as needed
validation_loader = DataLoader(validation_dataset, batch_size=20)

# Training and validation loop
num_epochs = 1

train_loss_history = []  # Store training loss
validation_loss_history = []  # Store validation loss

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode

    for i, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        print(f"Epoch {epoch + 1}/{num_epochs}, Train Step {i + 1}/{len(train_loader)}, Loss: {loss.item():.4f}")
    
        print(f"Images shape: {images.shape}")

        # Validation loop
        model.eval()  # Set the model to evaluation mode

        with torch.no_grad():
            validation_loss = 0.0
            for j, (val_images, val_labels) in enumerate(validation_loader):
                val_outputs = model(val_images)
                val_loss = criterion(val_outputs, val_labels)
                validation_loss += val_loss.item()
            
            avg_validation_loss = validation_loss / len(validation_loader)
            print(f"Epoch {epoch + 1}/{num_epochs}, Validation Loss: {avg_validation_loss:.4f}")

        train_loss_history.append(loss.item())
        validation_loss_history.append(avg_validation_loss)

    print(f"Epoch {epoch + 1}/{num_epochs} done!")

# Plot the training and validation loss history
plt.figure()
plt.plot(range(1, len(train_loss_history) + 1), train_loss_history, label='Train Loss')
plt.plot(range(1,len(validation_loss_history) + 1), validation_loss_history, label='Validation Loss')
plt.xlabel('Training iteration')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Epoch 1/1, Train Step 1/30, Loss: 0.7523
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.7441
# Epoch 1/1, Train Step 2/30, Loss: 0.7441
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.7296
# Epoch 1/1, Train Step 3/30, Loss: 0.7296
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.7038
# Epoch 1/1, Train Step 4/30, Loss: 0.7038
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.6485
# Epoch 1/1, Train Step 5/30, Loss: 0.6484
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.5511
# Epoch 1/1, Train Step 6/30, Loss: 0.5509
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.4044
# Epoch 1/1, Train Step 7/30, Loss: 0.4044
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2381
# Epoch 1/1, Train Step 8/30, Loss: 0.2385
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1189
# Epoch 1/1, Train Step 9/30, Loss: 0.1193
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0865
# Epoch 1/1, Train Step 10/30, Loss: 0.0875
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1014
# Epoch 1/1, Train Step 11/30, Loss: 0.1016
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1240
# Epoch 1/1, Train Step 12/30, Loss: 0.1258
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1407
# Epoch 1/1, Train Step 13/30, Loss: 0.1426
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1476
# Epoch 1/1, Train Step 14/30, Loss: 0.1490
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1445
# Epoch 1/1, Train Step 15/30, Loss: 0.1449
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1330
# Epoch 1/1, Train Step 16/30, Loss: 0.1358
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1160
# Epoch 1/1, Train Step 17/30, Loss: 0.1155
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0959
# Epoch 1/1, Train Step 18/30, Loss: 0.0979
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0748
# Epoch 1/1, Train Step 19/30, Loss: 0.0791
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0552
# Epoch 1/1, Train Step 20/30, Loss: 0.0552
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0394
# Epoch 1/1, Train Step 21/30, Loss: 0.0396
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0287
# Epoch 1/1, Train Step 22/30, Loss: 0.0293
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0221
# Epoch 1/1, Train Step 23/30, Loss: 0.0228
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0186
# Epoch 1/1, Train Step 24/30, Loss: 0.0192
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0178
# Epoch 1/1, Train Step 25/30, Loss: 0.0177
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0192
# Epoch 1/1, Train Step 26/30, Loss: 0.0195
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0222
# Epoch 1/1, Train Step 27/30, Loss: 0.0221
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0248
# Epoch 1/1, Train Step 28/30, Loss: 0.0246
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0254
# Epoch 1/1, Train Step 29/30, Loss: 0.0256
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0237
# Epoch 1/1, Train Step 30/30, Loss: 0.0241
# Images shape: torch.Size([10, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0206
# Epoch 1/1 done!

# %%
#Test the model on a sample image
sample_image = create_synthetic_dataset(num_samples=1)[0]
#visualize output for a sample image
model.eval()
with torch.no_grad():
    output = model(sample_image[0].unsqueeze(0))

#Print range of sample image, output and mask
print(f"Input Image range: ({torch.min(sample_image[0])}, {torch.max(sample_image[0])})")
print(f"Output range: ({torch.min(output)}, {torch.max(output)})")
print(f"Label range: ({torch.min(sample_image[1])}, {torch.max(sample_image[1])})")


# Visualize the output along with the input image and mask
plt.figure()
plt.subplot(1, 3, 1)
plt.imshow(sample_image[0][0].numpy(), cmap='gray')
plt.title("Input Image")
plt.axis('off')
plt.subplot(1, 3, 2)
plt.imshow(output[0][0].numpy(), cmap='gray')
plt.title("Output Probability Map")
plt.axis('off')
plt.subplot(1, 3, 3)
plt.imshow(sample_image[1][0].numpy(), cmap='gray')
plt.title("Input Mask")
plt.axis('off')
plt.show()
# Out:
# Input Image range: (-0.8096553087234497, 1.0)
# Output range: (-7.102828502655029, 0.1165953278541565)
# Label range: (0.0, 1.0)

# %%
#Generate data
train_dataset = generate_images(1000, 100, 100)
validation_dataset = generate_images(20, 100, 100)

# %%
#Train the model the data emulating the real data and plot the training and validation loss

# Define the model, loss function, and optimizer
model = ParticleDetectionUNet()
criterion = nn.BCEWithLogitsLoss()  # Binary Cross-Entropy Loss
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Load the synthetic training dataset
train_loader = DataLoader(train_dataset, batch_size=50, shuffle=True)

# Load a separate validation dataset
validation_loader = DataLoader(validation_dataset, batch_size=20)

# Training and validation loop
num_epochs = 1

train_loss_history = []  # Store training loss
validation_loss_history = []  # Store validation loss

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode

    for i, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        print(f"Epoch {epoch + 1}/{num_epochs}, Train Step {i + 1}/{len(train_loader)}, Loss: {loss.item():.4f}")
    
        print(f"Images shape: {images.shape}")

        # Validation loop
        model.eval()  # Set the model to evaluation mode

        with torch.no_grad():
            validation_loss = 0.0
            for j, (val_images, val_labels) in enumerate(validation_loader):
                val_outputs = model(val_images)
                val_loss = criterion(val_outputs, val_labels)
                validation_loss += val_loss.item()
            
            avg_validation_loss = validation_loss / len(validation_loader)
            print(f"Epoch {epoch + 1}/{num_epochs}, Validation Loss: {avg_validation_loss:.4f}")

        train_loss_history.append(loss.item())
        validation_loss_history.append(avg_validation_loss)

    print(f"Epoch {epoch + 1}/{num_epochs} done!")

# Plot the training and validation loss history
plt.figure()
plt.plot(range(1, len(train_loss_history) + 1), train_loss_history, label='Train Loss')
plt.plot(range(1,len(validation_loss_history) + 1), validation_loss_history, label='Validation Loss')
plt.xlabel('Training iteration')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Epoch 1/1, Train Step 1/160, Loss: 0.6862
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.6699
# Epoch 1/1, Train Step 2/160, Loss: 0.6699
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.6432
# Epoch 1/1, Train Step 3/160, Loss: 0.6433
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.5907
# Epoch 1/1, Train Step 4/160, Loss: 0.5907
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.4974
# Epoch 1/1, Train Step 5/160, Loss: 0.4975
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.3721
# Epoch 1/1, Train Step 6/160, Loss: 0.3725
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2771
# Epoch 1/1, Train Step 7/160, Loss: 0.2774
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2903
# Epoch 1/1, Train Step 8/160, Loss: 0.2930
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.3455
# Epoch 1/1, Train Step 9/160, Loss: 0.3464
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.3560
# Epoch 1/1, Train Step 10/160, Loss: 0.3579
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.3262
# Epoch 1/1, Train Step 11/160, Loss: 0.3261
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2834
# Epoch 1/1, Train Step 12/160, Loss: 0.2839
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2526
# Epoch 1/1, Train Step 13/160, Loss: 0.2536
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2466
# Epoch 1/1, Train Step 14/160, Loss: 0.2478
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2598
# Epoch 1/1, Train Step 15/160, Loss: 0.2597
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2742
# Epoch 1/1, Train Step 16/160, Loss: 0.2744
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2778
# Epoch 1/1, Train Step 17/160, Loss: 0.2777
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2691
# Epoch 1/1, Train Step 18/160, Loss: 0.2695
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2535
# Epoch 1/1, Train Step 19/160, Loss: 0.2525
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2387
# Epoch 1/1, Train Step 20/160, Loss: 0.2385
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2317
# Epoch 1/1, Train Step 21/160, Loss: 0.2312
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2334
# Epoch 1/1, Train Step 22/160, Loss: 0.2334
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2388
# Epoch 1/1, Train Step 23/160, Loss: 0.2380
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2422
# Epoch 1/1, Train Step 24/160, Loss: 0.2420
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2404
# Epoch 1/1, Train Step 25/160, Loss: 0.2396
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2339
# Epoch 1/1, Train Step 26/160, Loss: 0.2324
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2258
# Epoch 1/1, Train Step 27/160, Loss: 0.2256
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2196
# Epoch 1/1, Train Step 28/160, Loss: 0.2180
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2174
# Epoch 1/1, Train Step 29/160, Loss: 0.2170
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2183
# Epoch 1/1, Train Step 30/160, Loss: 0.2171
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2198
# Epoch 1/1, Train Step 31/160, Loss: 0.2197
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2196
# Epoch 1/1, Train Step 32/160, Loss: 0.2191
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2168
# Epoch 1/1, Train Step 33/160, Loss: 0.2164
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2123
# Epoch 1/1, Train Step 34/160, Loss: 0.2112
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2080
# Epoch 1/1, Train Step 35/160, Loss: 0.2076
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2053
# Epoch 1/1, Train Step 36/160, Loss: 0.2049
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2044
# Epoch 1/1, Train Step 37/160, Loss: 0.2041
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2042
# Epoch 1/1, Train Step 38/160, Loss: 0.2023
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2034
# Epoch 1/1, Train Step 39/160, Loss: 0.2015
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2009
# Epoch 1/1, Train Step 40/160, Loss: 0.1993
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1972
# Epoch 1/1, Train Step 41/160, Loss: 0.1960
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1933
# Epoch 1/1, Train Step 42/160, Loss: 0.1934
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1902
# Epoch 1/1, Train Step 43/160, Loss: 0.1886
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1882
# Epoch 1/1, Train Step 44/160, Loss: 0.1866
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1868
# Epoch 1/1, Train Step 45/160, Loss: 0.1864
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1853
# Epoch 1/1, Train Step 46/160, Loss: 0.1849
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1833
# Epoch 1/1, Train Step 47/160, Loss: 0.1828
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1810
# Epoch 1/1, Train Step 48/160, Loss: 0.1805
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1788
# Epoch 1/1, Train Step 49/160, Loss: 0.1782
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1771
# Epoch 1/1, Train Step 50/160, Loss: 0.1760
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1757
# Epoch 1/1, Train Step 51/160, Loss: 0.1742
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1740
# Epoch 1/1, Train Step 52/160, Loss: 0.1736
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1718
# Epoch 1/1, Train Step 53/160, Loss: 0.1715
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1694
# Epoch 1/1, Train Step 54/160, Loss: 0.1694
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1673
# Epoch 1/1, Train Step 55/160, Loss: 0.1666
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1655
# Epoch 1/1, Train Step 56/160, Loss: 0.1652
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1636
# Epoch 1/1, Train Step 57/160, Loss: 0.1625
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1611
# Epoch 1/1, Train Step 58/160, Loss: 0.1605
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1581
# Epoch 1/1, Train Step 59/160, Loss: 0.1571
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1552
# Epoch 1/1, Train Step 60/160, Loss: 0.1546
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1525
# Epoch 1/1, Train Step 61/160, Loss: 0.1517
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1499
# Epoch 1/1, Train Step 62/160, Loss: 0.1480
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1472
# Epoch 1/1, Train Step 63/160, Loss: 0.1463
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1447
# Epoch 1/1, Train Step 64/160, Loss: 0.1437
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1426
# Epoch 1/1, Train Step 65/160, Loss: 0.1424
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1406
# Epoch 1/1, Train Step 66/160, Loss: 0.1407
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1383
# Epoch 1/1, Train Step 67/160, Loss: 0.1389
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1364
# Epoch 1/1, Train Step 68/160, Loss: 0.1346
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1348
# Epoch 1/1, Train Step 69/160, Loss: 0.1335
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1332
# Epoch 1/1, Train Step 70/160, Loss: 0.1317
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1315
# Epoch 1/1, Train Step 71/160, Loss: 0.1313
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1301
# Epoch 1/1, Train Step 72/160, Loss: 0.1298
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1287
# Epoch 1/1, Train Step 73/160, Loss: 0.1276
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1272
# Epoch 1/1, Train Step 74/160, Loss: 0.1269
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1257
# Epoch 1/1, Train Step 75/160, Loss: 0.1247
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1239
# Epoch 1/1, Train Step 76/160, Loss: 0.1242
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1221
# Epoch 1/1, Train Step 77/160, Loss: 0.1216
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1204
# Epoch 1/1, Train Step 78/160, Loss: 0.1200
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1188
# Epoch 1/1, Train Step 79/160, Loss: 0.1190
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1174
# Epoch 1/1, Train Step 80/160, Loss: 0.1174
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1163
# Epoch 1/1, Train Step 81/160, Loss: 0.1160
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1156
# Epoch 1/1, Train Step 82/160, Loss: 0.1145
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1149
# Epoch 1/1, Train Step 83/160, Loss: 0.1148
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1141
# Epoch 1/1, Train Step 84/160, Loss: 0.1142
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1133
# Epoch 1/1, Train Step 85/160, Loss: 0.1131
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1124
# Epoch 1/1, Train Step 86/160, Loss: 0.1118
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1113
# Epoch 1/1, Train Step 87/160, Loss: 0.1114
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1104
# Epoch 1/1, Train Step 88/160, Loss: 0.1103
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1097
# Epoch 1/1, Train Step 89/160, Loss: 0.1087
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1090
# Epoch 1/1, Train Step 90/160, Loss: 0.1086
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1084
# Epoch 1/1, Train Step 91/160, Loss: 0.1079
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1078
# Epoch 1/1, Train Step 92/160, Loss: 0.1076
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1070
# Epoch 1/1, Train Step 93/160, Loss: 0.1064
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1062
# Epoch 1/1, Train Step 94/160, Loss: 0.1062
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1056
# Epoch 1/1, Train Step 95/160, Loss: 0.1062
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1053
# Epoch 1/1, Train Step 96/160, Loss: 0.1045
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1049
# Epoch 1/1, Train Step 97/160, Loss: 0.1049
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1040
# Epoch 1/1, Train Step 98/160, Loss: 0.1035
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1040
# Epoch 1/1, Train Step 99/160, Loss: 0.1044
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1039
# Epoch 1/1, Train Step 100/160, Loss: 0.1035
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1030
# Epoch 1/1, Train Step 101/160, Loss: 0.1019
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1029
# Epoch 1/1, Train Step 102/160, Loss: 0.1018
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1026
# Epoch 1/1, Train Step 103/160, Loss: 0.1019
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1020
# Epoch 1/1, Train Step 104/160, Loss: 0.1009
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1019
# Epoch 1/1, Train Step 105/160, Loss: 0.1007
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1015
# Epoch 1/1, Train Step 106/160, Loss: 0.1010
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1011
# Epoch 1/1, Train Step 107/160, Loss: 0.1001
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1010
# Epoch 1/1, Train Step 108/160, Loss: 0.1013
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1006
# Epoch 1/1, Train Step 109/160, Loss: 0.1005
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1004
# Epoch 1/1, Train Step 110/160, Loss: 0.0999
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1001
# Epoch 1/1, Train Step 111/160, Loss: 0.1010
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0999
# Epoch 1/1, Train Step 112/160, Loss: 0.0996
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0997
# Epoch 1/1, Train Step 113/160, Loss: 0.1004
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0996
# Epoch 1/1, Train Step 114/160, Loss: 0.0990
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0992
# Epoch 1/1, Train Step 115/160, Loss: 0.0990
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0992
# Epoch 1/1, Train Step 116/160, Loss: 0.0984
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0991
# Epoch 1/1, Train Step 117/160, Loss: 0.0984
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0987
# Epoch 1/1, Train Step 118/160, Loss: 0.0968
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0986
# Epoch 1/1, Train Step 119/160, Loss: 0.0981
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0985
# Epoch 1/1, Train Step 120/160, Loss: 0.0985
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0982
# Epoch 1/1, Train Step 121/160, Loss: 0.0975
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0980
# Epoch 1/1, Train Step 122/160, Loss: 0.0990
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0979
# Epoch 1/1, Train Step 123/160, Loss: 0.0971
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0978
# Epoch 1/1, Train Step 124/160, Loss: 0.0974
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0976
# Epoch 1/1, Train Step 125/160, Loss: 0.0965
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0974
# Epoch 1/1, Train Step 126/160, Loss: 0.0980
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0973
# Epoch 1/1, Train Step 127/160, Loss: 0.0974
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0972
# Epoch 1/1, Train Step 128/160, Loss: 0.0967
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0970
# Epoch 1/1, Train Step 129/160, Loss: 0.0955
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0969
# Epoch 1/1, Train Step 130/160, Loss: 0.0976
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0967
# Epoch 1/1, Train Step 131/160, Loss: 0.0970
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0966
# Epoch 1/1, Train Step 132/160, Loss: 0.0971
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0965
# Epoch 1/1, Train Step 133/160, Loss: 0.0965
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0964
# Epoch 1/1, Train Step 134/160, Loss: 0.0965
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0964
# Epoch 1/1, Train Step 135/160, Loss: 0.0963
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0963
# Epoch 1/1, Train Step 136/160, Loss: 0.0966
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0960
# Epoch 1/1, Train Step 137/160, Loss: 0.0961
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0959
# Epoch 1/1, Train Step 138/160, Loss: 0.0958
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0958
# Epoch 1/1, Train Step 139/160, Loss: 0.0945
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0959
# Epoch 1/1, Train Step 140/160, Loss: 0.0956
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0956
# Epoch 1/1, Train Step 141/160, Loss: 0.0958
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0954
# Epoch 1/1, Train Step 142/160, Loss: 0.0960
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0953
# Epoch 1/1, Train Step 143/160, Loss: 0.0963
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0952
# Epoch 1/1, Train Step 144/160, Loss: 0.0938
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0951
# Epoch 1/1, Train Step 145/160, Loss: 0.0937
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0950
# Epoch 1/1, Train Step 146/160, Loss: 0.0953
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0949
# Epoch 1/1, Train Step 147/160, Loss: 0.0947
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0948
# Epoch 1/1, Train Step 148/160, Loss: 0.0947
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0946
# Epoch 1/1, Train Step 149/160, Loss: 0.0946
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0945
# Epoch 1/1, Train Step 150/160, Loss: 0.0933
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0944
# Epoch 1/1, Train Step 151/160, Loss: 0.0958
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0943
# Epoch 1/1, Train Step 152/160, Loss: 0.0943
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0943
# Epoch 1/1, Train Step 153/160, Loss: 0.0943
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0943
# Epoch 1/1, Train Step 154/160, Loss: 0.0943
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0945
# Epoch 1/1, Train Step 155/160, Loss: 0.0945
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0949
# Epoch 1/1, Train Step 156/160, Loss: 0.0943
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0948
# Epoch 1/1, Train Step 157/160, Loss: 0.0946
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0938
# Epoch 1/1, Train Step 158/160, Loss: 0.0932
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0937
# Epoch 1/1, Train Step 159/160, Loss: 0.0935
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0940
# Epoch 1/1, Train Step 160/160, Loss: 0.0948
# Images shape: torch.Size([25, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.0936
# Epoch 1/1 done!

# %%
#Test the model on a sample image
sample_image = generate_images(1, 100, 100)[0]
#visualize output for a sample image
model.eval()
with torch.no_grad():
    output = model(sample_image[0].unsqueeze(0))

#Print range of sample image, output and mask
print(f"Input Image range: ({torch.min(sample_image[0])}, {torch.max(sample_image[0])})")
print(f"Output range: ({torch.min(output)}, {torch.max(output)})")
print(f"Label range: ({torch.min(sample_image[1])}, {torch.max(sample_image[1])})")


# Visualize the output along with the input image and mask
plt.figure()
plt.subplot(1, 3, 1)
plt.imshow(sample_image[0][0].numpy(), cmap='gray')
plt.title("Input Image")
plt.axis('off')
plt.subplot(1, 3, 2)
plt.imshow(output[0][0].numpy(), cmap='gray')
plt.title("Output Probability Map")
plt.axis('off')
plt.subplot(1, 3, 3)
plt.imshow(sample_image[1][0].numpy(), cmap='gray')
plt.title("Input Mask")
plt.axis('off')
plt.show()
# Out:
# Input Image range: (-0.7456300854682922, 1.72017502784729)
# Output range: (-12.575713157653809, 7.712697982788086)
# Label range: (0.0, 1.6065306663513184)

# %%
"""
This is not done yet. I think it is right up until the point where we need to pass the output of the UNet to the LSTM.
"""
#Making a new model combining UNet and LSTM
class ParticleDetectionModel(nn.Module):
    def __init__(self, input_channels=1, num_classes=1, num_filters=64):
        super(ParticleDetectionModel, self).__init__()
        
        # U-Net Architecture for Frame-Level Detection
        self.encoder = nn.Sequential(
            nn.Conv2d(input_channels, num_filters, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(num_filters, num_filters, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.middle = nn.Sequential(
            nn.Conv2d(num_filters, num_filters, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(num_filters, num_filters, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(num_filters, num_filters, kernel_size=2, stride=2),
            nn.ConvTranspose2d(num_filters, num_filters, kernel_size=2, stride=2),
            nn.Conv2d(num_filters, num_classes, kernel_size=1)
        )
        
        # Bidirectional LSTM for Temporal Consistency
        self.lstm = nn.LSTM(input_size=num_classes, hidden_size=num_classes, num_layers=2, batch_first=True, bidirectional=True)
        
    def forward(self, frames):
        # U-Net Forward Pass
        features = []
        for frame in frames:
            x = self.encoder(frame)
            x = self.middle(x)
            x = self.decoder(x)
            features.append(x)
        

        # Concatenate the features from all frames
        x = torch.cat(features, dim=1)

        # Reshape the features to match LSTM input dimensions
        #batch_size, num_channels, H, W = x.size()
        #x = x.view(batch_size, -1, num_channels * H * W)


        # Bidirectional LSTM Forward Pass
        #lstm_out, _ = self.lstm(x)

    
        
        # Output: Probability Maps for Each Frame
        #probability_maps = torch.sigmoid(lstm_out)
        
        #return lstm_out

        return x
        #return probability_maps

# %%
# Create a dummy input tensor
# Assuming your input is a sequence of 10 grayscale images of size 64x64
dummy_input = torch.randn(1, 10, 1, 64, 64)  # (batch_size, sequence_length, channels, height, width)

model_unet_lstm = ParticleDetectionModel()

# Pass the dummy input through the model
output = model_unet_lstm(dummy_input)

print(output.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\farim\Desktop\particle_tracking_02456\notebooks\Network first draft notebook.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/farim/Desktop/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> # Create a dummy input tensor
#       <a href='vscode-notebook-cell:/c%3A/Users/farim/Desktop/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> # Assuming your input is a sequence of 10 grayscale images of size 64x64
# ----> <a href='vscode-notebook-cell:/c%3A/Users/farim/Desktop/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> dummy_input = torch.randn(1, 10, 1, 64, 64)  # (batch_size, sequence_length, channels, height, width)
#       <a href='vscode-notebook-cell:/c%3A/Users/farim/Desktop/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> model_unet_lstm = ParticleDetectionModel()
#       <a href='vscode-notebook-cell:/c%3A/Users/farim/Desktop/particle_tracking_02456/notebooks/Network%20first%20draft%20notebook.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> # Pass the dummy input through the model
#
# NameError: name 'torch' is not defined

# %%
class ParticleDetectionUNetIte2(nn.Module):
    def __init__(self, in_channels=1, out_channels=1, features=64):
        super(ParticleDetectionUNetIte2, self).__init__()
        
        # Encoder (downsampling)
    
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels, features, kernel_size=3, padding=1),
            nn.BatchNorm2d(features),
            nn.ReLU(inplace=True),
            nn.Conv2d(features, features, kernel_size=3, padding=1),
            nn.BatchNorm2d(features),
            nn.ReLU(inplace=True),
        )
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Bottleneck
        self.bottleneck = nn.Sequential(
            nn.Conv2d(features, features * 2, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(features * 2, features * 2, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        
        # Decoder (upsampling)
        self.upconv1 = nn.ConvTranspose2d(features * 2, features, kernel_size=2, stride=2)
        self.conv2 = nn.Sequential(
            nn.Conv2d(features * 2, features, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(features, out_channels, kernel_size=1)  # Output layer
        )

    def forward(self, x):
        # Encoder
        x1 = self.conv1(x)
        x2 = self.pool1(x1)
        
        # Bottleneck
        x3 = self.bottleneck(x2)
        
        # Decoder
        x4 = self.upconv1(x3)
        x5 = torch.cat([x4, x1], dim=1)  # Skip connection
        x6 = self.conv2(x5)
        
        return x6

# %%
#Train the model the data emulating the real data and plot the training and validation loss

# Define the model, loss function, and optimizer
model = ParticleDetectionUNetIte2()
criterion = nn.BCEWithLogitsLoss()  # Binary Cross-Entropy Loss
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Load the synthetic training dataset
train_loader = DataLoader(train_dataset, batch_size=50, shuffle=True)

# Load a separate validation dataset
validation_loader = DataLoader(validation_dataset, batch_size=20)

# Training and validation loop
num_epochs = 1

train_loss_history = []  # Store training loss
validation_loss_history = []  # Store validation loss

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode

    for i, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        print(f"Epoch {epoch + 1}/{num_epochs}, Train Step {i + 1}/{len(train_loader)}, Loss: {loss.item():.4f}")
    
        print(f"Images shape: {images.shape}")

        # Validation loop
        model.eval()  # Set the model to evaluation mode

        with torch.no_grad():
            validation_loss = 0.0
            for j, (val_images, val_labels) in enumerate(validation_loader):
                val_outputs = model(val_images)
                val_loss = criterion(val_outputs, val_labels)
                validation_loss += val_loss.item()
            
            avg_validation_loss = validation_loss / len(validation_loader)
            print(f"Epoch {epoch + 1}/{num_epochs}, Validation Loss: {avg_validation_loss:.4f}")

        train_loss_history.append(loss.item())
        validation_loss_history.append(avg_validation_loss)

    print(f"Epoch {epoch + 1}/{num_epochs} done!")

# Plot the training and validation loss history
plt.figure()
plt.plot(range(1, len(train_loss_history) + 1), train_loss_history, label='Train Loss')
plt.plot(range(1,len(validation_loss_history) + 1), validation_loss_history, label='Validation Loss')
plt.xlabel('Training iteration')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Epoch 1/1, Train Step 1/20, Loss: 0.6831
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.6768
# Epoch 1/1, Train Step 2/20, Loss: 0.6768
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.5910
# Epoch 1/1, Train Step 3/20, Loss: 0.5909
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.4384
# Epoch 1/1, Train Step 4/20, Loss: 0.4385
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2690
# Epoch 1/1, Train Step 5/20, Loss: 0.2690
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.3133
# Epoch 1/1, Train Step 6/20, Loss: 0.3148
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.3606
# Epoch 1/1, Train Step 7/20, Loss: 0.3600
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.3122
# Epoch 1/1, Train Step 8/20, Loss: 0.3136
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2492
# Epoch 1/1, Train Step 9/20, Loss: 0.2500
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2209
# Epoch 1/1, Train Step 10/20, Loss: 0.2213
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2237
# Epoch 1/1, Train Step 11/20, Loss: 0.2238
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2304
# Epoch 1/1, Train Step 12/20, Loss: 0.2303
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2277
# Epoch 1/1, Train Step 13/20, Loss: 0.2280
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.2160
# Epoch 1/1, Train Step 14/20, Loss: 0.2161
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1998
# Epoch 1/1, Train Step 15/20, Loss: 0.2000
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1841
# Epoch 1/1, Train Step 16/20, Loss: 0.1843
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1719
# Epoch 1/1, Train Step 17/20, Loss: 0.1719
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1643
# Epoch 1/1, Train Step 18/20, Loss: 0.1645
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1603
# Epoch 1/1, Train Step 19/20, Loss: 0.1602
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1577
# Epoch 1/1, Train Step 20/20, Loss: 0.1578
# Images shape: torch.Size([50, 1, 100, 100])
# Epoch 1/1, Validation Loss: 0.1547
# Epoch 1/1 done!

# %%
#Test the model on a sample image
sample_image = generate_images(1, 100, 100)[0]
#visualize output for a sample image
model.eval()
with torch.no_grad():
    output = model(sample_image[0].unsqueeze(0))

#Print range of sample image, output and mask
print(f"Input Image range: ({torch.min(sample_image[0])}, {torch.max(sample_image[0])})")
print(f"Output range: ({torch.min(output)}, {torch.max(output)})")
print(f"Label range: ({torch.min(sample_image[1])}, {torch.max(sample_image[1])})")


# Visualize the output along with the input image and mask
plt.figure()
plt.subplot(1, 3, 1)
plt.imshow(sample_image[0][0].numpy(), cmap='gray')
plt.title("Input Image")
plt.axis('off')
plt.subplot(1, 3, 2)
plt.imshow(output[0][0].numpy(), cmap='gray')
plt.title("Output Probability Map")
plt.axis('off')
plt.subplot(1, 3, 3)
plt.imshow(sample_image[1][0].numpy(), cmap='gray')
plt.title("Input Mask")
plt.axis('off')
plt.show()
# Out:
# Input Image range: (-0.8182787299156189, 1.8874475955963135)
# Output range: (-6.976637840270996, -0.5761749744415283)
# Label range: (0.0, 1.6886156797409058)
